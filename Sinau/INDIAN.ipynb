# %%
# Mengimpor library yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Mengatur style visualisasi agar lebih menarik
sns.set_theme(style="whitegrid")

print("Library berhasil diimpor!")

# %%
url = 'https://raw.githubusercontent.com/4K-AN/My-Playfield/main/Tugas/DATSI/DATASET/student_habits.csv'

try:
    # Membaca file CSV langsung dari URL
    df = pd.read_csv(url)

    print("✅ Dataset berhasil dimuat langsung dari link GitHub ")
    print("\nBerikut adalah 5 baris pertama dari data Anda:")
    display(df.head())

except Exception as e:
    print(f"❌ GAGAL: Terjadi error saat memuat data dari URL.")
    print("   Pastikan beberapa hal berikut:")
    print("   1. URL sudah benar dan merupakan versi 'Raw'.")
    print("   2. Repositori GitHub Anda bersifat 'Public'.")
    print(f"   3. Detail Error: {e}")
